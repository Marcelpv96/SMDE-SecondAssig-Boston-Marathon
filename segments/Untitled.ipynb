# %%
import pandas as pd

df = pd.read_csv('5k.csv')
df2 = pd.read_csv('10k.csv')
df3 = pd.read_csv('15k.csv')
df4 = pd.read_csv('20k.csv')
df5 = pd.read_csv('25k.csv')
df6 = pd.read_csv('30k.csv')
df7 = pd.read_csv('40k.csv')

all_df = pd.concat([df, df2,df3,df4,df5,df6,df7])

df = pd.read_csv('../2016.csv')
df[df['Age']==43]
# Out:
#        Unnamed: 0    Bib                           Name  Age M/F  \
# 71             75     86                 Stein, Russell   43   M
# 128           134     83               Pearson, Neil F.   43   M
# 133           139    924               Zelazny, Derek J   43   M
# 198           204    640                 Lindbo, Torrey   43   M
# 264           273    589            Carrington, Boyd J.   43   M
# 330           339    488                   Aitken, Kyle   43   M
# 371           380    988           Callahan, Patrick M.   43   M
# 421           430   3863                 Trampe, Travis   43   M
# 431           440   2967                  Bourque, Yves   43   M
# 448           457   1391                 Kramer, Robert   43   M
# 479           488   4863                  Preslar, Matt   43   M
# 505           514    673              Ferguson, Mark D.   43   M
# 562           571   1748         Bonvillain, Frederic X   43   M
# ...
